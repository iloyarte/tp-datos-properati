# %%
import numpy as np
import pandas as pd

# plots
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
properties = pd.read_csv('properati-AR-2017-08-01-properties-sell.csv')

# %%
properties.dtypes
# Out:
# id                                    object
# created_on                    datetime64[ns]
# operation                             object
# property_type                         object
# place_name                            object
# place_with_parent_names               object
# country_name                          object
# state_name                            object
# geonames_id                          float64
# lat-lon                               object
# lat                                  float64
# lon                                  float64
# price                                float64
# currency                              object
# price_aprox_local_currency           float64
# price_aprox_usd                      float64
# surface_total_in_m2                  float64
# surface_covered_in_m2                float64
# price_usd_per_m2                     float64
# price_per_m2                         float64
# floor                                float64
# ...

# %%
properties.head(10)
# Out:
#                                           id created_on operation  \
# 0   c8a66ee9e3da083ab66dacd165e8a5cc718b1cf2 2012-09-19      sell
# 1   a205c53378e7879cf7519659317fb410c060d20e 2012-10-22      sell
# 4   9446052c949050359fb08b9f1ba83ba2eaa20c99 2012-12-08      sell
# 5   4d3b492ed5f9c74cdf33b56b98328e5c950e3f9c 2013-01-04      sell
# 6   535441f569473f6e5d687c38b27d9b9c6e69e284 2013-01-09      sell
# 10  61f3789618edabeaa7b5fc06ff36112f8a06557f 2013-01-26      sell
# 12  e842ed22eac89b9bffff146377abfd5bceb0b0cd 2013-02-08      sell
# 13  4dcfa9a54bdd18cd5438221c6dcfa94738c11c40 2013-02-15      sell
# 28  c60df01c06fe62d91c4767830ee14890fa4d73ec 2013-03-23      sell
# 29  0f0e301809a14b8c069b267fa1c56a3b5ec35d9e 2013-03-23      sell
#
#    property_type            place_name  \
# 0          house  San Antonio De Padua
# 1          house  San Antonio De Padua
# 4          house             Mataderos
# 5      apartment                 Pilar
# ...

# %%
# Convierto la columna de fecha en un datetime.
properties.created_on = pd.to_datetime(properties.created_on)

# %%
# Filtro los resultados que no son de caba.
properties = properties.loc[properties['state_name'].isin(['Capital Federal', 'Bs.As. G.B.A. Zona Sur','Bs.As. G.B.A. Zona Norte','Bs.As. G.B.A. Zona Oeste'])]

# %%
def filter():

# %%
grouped_by_parent_names = properties.groupby('place')
grouped_by_parent_names.describe()['price']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-5e4d0655ec44> in <module>()
# ----> 1 grouped_by_parent_names = properties.groupby('place')
#       2 grouped_by_parent_names.describe()['price']
#
# /home/ivo/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    4269         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    4270                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 4271                        **kwargs)
#    4272
#    4273     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# /home/ivo/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in groupby(obj, by, **kwds)
#    1624         raise TypeError('invalid type: %s' % type(obj))
#    1625
# ...

# %%
for group in grouped_by_parent_names:
    if group.price.count
